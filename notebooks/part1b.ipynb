# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
attendance_metadata = "..\data\cleaned_data_schoolattendancerate_seifa.csv"
attendance_df = pd.read_csv(attendance_metadata)


attendance_df.head(10)
# Out:
#   School Code                   School  Attendance Year   School Type  \
# 0         591    Abercorn State School             2015  State School
# 1         591    Abercorn State School             2016  State School
# 2         591    Abercorn State School             2017  State School
# 3         591    Abercorn State School             2018  State School
# 4         591    Abercorn State School             2019  State School
# 5        1275  Abergowrie State School             2015  State School
# 6        1275  Abergowrie State School             2016  State School
# 7        1275  Abergowrie State School             2017  State School
# 8        1275  Abergowrie State School             2018  State School
# 9        1275  Abergowrie State School             2019  State School
#
#   School Category           Remoteness Area              Region  \
# 0         Primary  Outer Regional Australia  Central Queensland
# 1         Primary  Outer Regional Australia  Central Queensland
# 2         Primary  Outer Regional Australia  Central Queensland
# 3         Primary  Outer Regional Australia  Central Queensland
# 4         Primary  Outer Regional Australia  Central Queensland
# 5         Primary          Remote Australia    North Queensland
# 6         Primary          Remote Australia    North Queensland
# 7         Primary          Remote Australia    North Queensland
# 8         Primary          Remote Australia    North Queensland
# 9         Primary          Remote Australia    North Queensland
#
#   Local Government Area State Electorate  FTE Days Attended  \
# 0     North Burnett (R)          Callide             1987.5
# 1     North Burnett (R)          Callide             1632.5
# 2     North Burnett (R)          Callide             1405.0
# 3     North Burnett (R)          Callide             1640.0
# 4     North Burnett (R)          Callide             1657.5
# 5      Hinchinbrook (S)     Hinchinbrook             1007.0
# 6      Hinchinbrook (S)     Hinchinbrook              420.5
# 7      Hinchinbrook (S)     Hinchinbrook              371.5
# 8      Hinchinbrook (S)     Hinchinbrook              614.0
# 9      Hinchinbrook (S)     Hinchinbrook              596.0
#
#    Possible Attendance Days  Attendance Rate  SEIFA Territory Percentile  \
# 0                    2103.0             94.5                        11.0
# 1                    1705.0             95.7                        11.0
# 2                    1440.0             97.6                        11.0
# 3                    1700.0             96.5                        11.0
# 4                    1728.0             95.9                        11.0
# 5                    1067.0             94.4                        27.0
# 6                     484.0             86.9                        27.0
# 7                     384.0             96.7                        27.0
# 8                     679.0             90.4                        27.0
# 9                     652.0             91.4                        27.0
#
#   Official Low Year Level Official High Year Level      Suburb  Post Code  \
# 0               Prep Year                   Year 6    Abercorn       4627
# 1               Prep Year                   Year 6    Abercorn       4627
# 2               Prep Year                   Year 6    Abercorn       4627
# 3               Prep Year                   Year 6    Abercorn       4627
# 4               Prep Year                   Year 6    Abercorn       4627
# 5               Prep Year                   Year 6  Abergowrie       4850
# 6               Prep Year                   Year 6  Abergowrie       4850
# 7               Prep Year                   Year 6  Abergowrie       4850
# 8               Prep Year                   Year 6  Abergowrie       4850
# 9               Prep Year                   Year 6  Abergowrie       4850
#
#    All Student Count   Longitude   Latitude
# 0               18.0  151.127031 -25.135955
# 1               18.0  151.127031 -25.135955
# 2               18.0  151.127031 -25.135955
# 3               18.0  151.127031 -25.135955
# 4               18.0  151.127031 -25.135955
# 5                4.0  145.883510 -18.474697
# 6                4.0  145.883510 -18.474697
# 7                4.0  145.883510 -18.474697
# 8                4.0  145.883510 -18.474697
# 9                4.0  145.883510 -18.474697

# %%
for year in range(2015,2020):
    
    attendance_year_df=attendance_df.loc[attendance_df['Attendance Year']==year]
    mean_year=attendance_year_df.groupby(['School Type'])['Attendance Rate'].mean()
    print(year, mean_year)
# Out:
# 2015 School Type
# Community School            67.500000
# Special School              88.404762
# Specific Purpose School    100.000000
# State High School           89.458470
# State School                92.231073
# Name: Attendance Rate, dtype: float64
# 2016 School Type
# Community School            68.400000
# Special School              88.430952
# Specific Purpose School    100.000000
# State High School           89.490164
# State School                92.274874
# Name: Attendance Rate, dtype: float64
# 2017 School Type
# Community School            69.600000
# Special School              87.462791
# Specific Purpose School    100.000000
# State High School           89.573370
# State School                92.067976
# Name: Attendance Rate, dtype: float64
# 2018 School Type
# Community School     75.100000
# Special School       86.320930
# State High School    88.549730
# State School         91.600401
# Name: Attendance Rate, dtype: float64
# 2019 School Type
# Community School          70.300000
# Special Purpose School    95.100000
# Special School            85.993023
# State High School         88.154595
# State School              91.070341
# Name: Attendance Rate, dtype: float64

# %%
df2 =attendance_df.iloc[:,[2,3,11]]
df2
df3 = df2.groupby(['Attendance Year','School Type']).mean().reset_index()
# df4 = pd.pivot_table(df3,values = 'Attendance Rate',index=['Attendance Year'],columns = ['School Type']).reset_index()
df = df3.pivot(index='Attendance Year', columns='School Type',values='Attendance Rate')
df
# Out:
# School Type      Community School  Special Purpose School  Special School  \
# Attendance Year
# 2015                         67.5                     NaN       88.404762
# 2016                         68.4                     NaN       88.430952
# 2017                         69.6                     NaN       87.462791
# 2018                         75.1                     NaN       86.320930
# 2019                         70.3                    95.1       85.993023
#
# School Type      Specific Purpose School  State High School  State School
# Attendance Year
# 2015                               100.0          89.458470     92.231073
# 2016                               100.0          89.490164     92.274874
# 2017                               100.0          89.573370     92.067976
# 2018                                 NaN          88.549730     91.600401
# 2019                                 NaN          88.154595     91.070341

# %%
a=df.plot(kind="bar",title="Attendance Rate VS School Type",figsize=(12,8)).legend(
    loc='upper center', ncol=3, title="School Type")
plt.ylabel('Attendance Rate')

plt.show()

# %%
plt.savefig('part1b_fig1.png')
