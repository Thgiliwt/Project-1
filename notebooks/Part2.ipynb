# %% [markdown]
# # Part 2 - Attendance rate per geographic region
# This notebook explores the attendance rate per geographic Region
# ## Output
# A bar graph of attendance rate per region as a bar graph
# ```../data/fig1_part2_Attendance Rate & Region_bar.png```
#
# A pie chart of fraction of total attendance per region
# ```'../data/fig2_part2_Attendance Rate & Region_pie.png```
#
# A line plot of attendance rate per Region
# ```../data/fig3_Part2_Attendance Rate & LGA_line.png```
#
# Note: LGA classifcation codes:
# Queensland: Cities (C), Shires (S), Towns (T) and Regional Councils (R)

# %%
import pandas as pd
import matplotlib.pyplot as plt
import scipy.stats as st
import numpy as np

file = '../data/cleaned_data_schoolattendancerate.csv'

# %%
#read cleaned data
df1 = pd.read_csv(file)
df1.head()
# Out:
#   School Code                 School  Attendance Year   School Type  \
# 0         591  Abercorn State School             2015  State School
# 1         591  Abercorn State School             2016  State School
# 2         591  Abercorn State School             2017  State School
# 3         591  Abercorn State School             2018  State School
# 4         591  Abercorn State School             2019  State School
#
#   School Category           Remoteness Area              Region  \
# 0         Primary  Outer Regional Australia  Central Queensland
# 1         Primary  Outer Regional Australia  Central Queensland
# 2         Primary  Outer Regional Australia  Central Queensland
# 3         Primary  Outer Regional Australia  Central Queensland
# 4         Primary  Outer Regional Australia  Central Queensland
#
#   Local Government Area State Electorate  FTE Days Attended  \
# 0     North Burnett (R)          Callide             1987.5
# 1     North Burnett (R)          Callide             1632.5
# 2     North Burnett (R)          Callide             1405.0
# 3     North Burnett (R)          Callide             1640.0
# 4     North Burnett (R)          Callide             1657.5
#
#    Possible Attendance Days  Attendance Rate Official Low Year Level  \
# 0                    2103.0             94.5               Prep Year
# 1                    1705.0             95.7               Prep Year
# 2                    1440.0             97.6               Prep Year
# 3                    1700.0             96.5               Prep Year
# 4                    1728.0             95.9               Prep Year
#
#   Official High Year Level    Suburb  Post Code  All Student Count  \
# 0                   Year 6  Abercorn       4627               18.0
# 1                   Year 6  Abercorn       4627               18.0
# 2                   Year 6  Abercorn       4627               18.0
# 3                   Year 6  Abercorn       4627               18.0
# 4                   Year 6  Abercorn       4627               18.0
#
#     Longitude   Latitude
# 0  151.127031 -25.135955
# 1  151.127031 -25.135955
# 2  151.127031 -25.135955
# 3  151.127031 -25.135955
# 4  151.127031 -25.135955

# %%
#check data info
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6109 entries, 0 to 6108
# Data columns (total 19 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   School Code               6109 non-null   object
#  1   School                    6109 non-null   object
#  2   Attendance Year           6109 non-null   int64
#  3   School Type               6109 non-null   object
#  4   School Category           6109 non-null   object
#  5   Remoteness Area           6109 non-null   object
#  6   Region                    6109 non-null   object
#  7   Local Government Area     6109 non-null   object
#  8   State Electorate          6109 non-null   object
#  9   FTE Days Attended         6109 non-null   float64
#  10  Possible Attendance Days  6109 non-null   float64
#  11  Attendance Rate           6109 non-null   float64
#  12  Official Low Year Level   6109 non-null   object
#  13  Official High Year Level  6109 non-null   object
#  14  Suburb                    6109 non-null   object
#  15  Post Code                 6109 non-null   int64
#  16  All Student Count         6109 non-null   float64
#  17  Longitude                 6109 non-null   float64
#  18  Latitude                  6109 non-null   float64
# dtypes: float64(6), int64(2), object(11)
# memory usage: 906.9+ KB

# %%
#check at details
df1['School Code'].value_counts()
# Out:
# 1714    5
# 491     5
# 702     5
# 3045    5
# 1221    5
#        ..
# A069    2
# 9315    2
# 3036    2
# A109    2
# A657    1
# Name: School Code, Length: 1228, dtype: int64

# %%
#check at details
df1['Attendance Year'].value_counts()
# Out:
# 2019    1228
# 2018    1226
# 2017    1222
# 2016    1218
# 2015    1215
# Name: Attendance Year, dtype: int64

# %%
#check at details
df1['Local Government Area'].value_counts()
# Out:
# Brisbane (C)          911
# Moreton Bay (R)       341
# Gold Coast (C)        337
# Toowoomba (R)         290
# Logan (C)             257
#                      ...
# Burke (S)               5
# Richmond (S)            5
# Lockhart River (S)      5
# Kowanyama (S)           5
# Hope Vale (S)           1
# Name: Local Government Area, Length: 74, dtype: int64

# %%
#check at details
df1['Region'].value_counts()
# Out:
# Metropolitan                1232
# North Coast                 1088
# Darling Downs South West    1030
# Central Queensland           925
# South East                   829
# North Queensland             527
# Far North Queensland         478
# Name: Region, dtype: int64

# %%
#select interested data and form new dfs
df2 = df1.iloc[:,[2,6,7,11]]
df3 = df2.groupby(['Attendance Year','Region']).mean().reset_index()
df3
# Out:
#     Attendance Year                    Region  Attendance Rate
# 0              2015        Central Queensland        92.442162
# 1              2015  Darling Downs South West        92.225728
# 2              2015      Far North Queensland        89.330526
# 3              2015              Metropolitan        92.614344
# 4              2015               North Coast        91.470233
# 5              2015          North Queensland        89.814286
# 6              2015                South East        91.481818
# 7              2016        Central Queensland        92.449730
# 8              2016  Darling Downs South West        92.077670
# 9              2016      Far North Queensland        89.190526
# 10             2016              Metropolitan        92.858367
# 11             2016               North Coast        91.588940
# 12             2016          North Queensland        89.531429
# 13             2016                South East        91.717576
# 14             2017        Central Queensland        92.011351
# 15             2017  Darling Downs South West        91.860680
# 16             2017      Far North Queensland        89.041667
# 17             2017              Metropolitan        92.700810
# 18             2017               North Coast        91.486697
# 19             2017          North Queensland        89.307619
# 20             2017                South East        91.658182
# 21             2018        Central Queensland        91.354054
# 22             2018  Darling Downs South West        91.500485
# 23             2018      Far North Queensland        88.559375
# 24             2018              Metropolitan        92.025911
# 25             2018               North Coast        90.742009
# 26             2018          North Queensland        88.788679
# 27             2018                South East        91.188024
# 28             2019        Central Queensland        90.886486
# 29             2019  Darling Downs South West        91.176214
# 30             2019      Far North Queensland        87.502083
# 31             2019              Metropolitan        91.579116
# 32             2019               North Coast        90.396347
# 33             2019          North Queensland        87.700943
# 34             2019                South East        90.820958

# %%
#change the view for plotting
df4 = pd.pivot_table(df3,values = 'Attendance Rate',index=['Attendance Year'],columns = ['Region']).reset_index()
df4
# Out:
# Region  Attendance Year  Central Queensland  Darling Downs South West  \
# 0                  2015           92.442162                 92.225728
# 1                  2016           92.449730                 92.077670
# 2                  2017           92.011351                 91.860680
# 3                  2018           91.354054                 91.500485
# 4                  2019           90.886486                 91.176214
#
# Region  Far North Queensland  Metropolitan  North Coast  North Queensland  \
# 0                  89.330526     92.614344    91.470233         89.814286
# 1                  89.190526     92.858367    91.588940         89.531429
# 2                  89.041667     92.700810    91.486697         89.307619
# 3                  88.559375     92.025911    90.742009         88.788679
# 4                  87.502083     91.579116    90.396347         87.700943
#
# Region  South East
# 0        91.481818
# 1        91.717576
# 2        91.658182
# 3        91.188024
# 4        90.820958

# %%
# make the bar plots of attendance rate per region
df4x = df4.set_index('Attendance Year')

barplot = df4x.plot(kind='bar',figsize=(40,20));
plt.title('Avg Attendance Rate for each Region of per year',fontsize=40)
plt.ylabel('Avg Attendance Rate',fontsize=40)
plt.xlabel('Attendance Year',fontsize=40)
plt.ylim(0,110)
barplot.set_xticklabels(df4x.index,rotation = 0,fontsize=20)
plt.grid()
plt.savefig('../data/fig1_part2_Attendance Rate & Region_bar.png')

# %%
df4a = df2.groupby(['Attendance Year','Region'])['Attendance Rate'].count().reset_index()
df4a
# Out:
#     Attendance Year                    Region  Attendance Rate
# 0              2015        Central Queensland              185
# 1              2015  Darling Downs South West              206
# 2              2015      Far North Queensland               95
# 3              2015              Metropolitan              244
# 4              2015               North Coast              215
# 5              2015          North Queensland              105
# 6              2015                South East              165
# 7              2016        Central Queensland              185
# 8              2016  Darling Downs South West              206
# 9              2016      Far North Queensland               95
# 10             2016              Metropolitan              245
# 11             2016               North Coast              217
# 12             2016          North Queensland              105
# 13             2016                South East              165
# 14             2017        Central Queensland              185
# 15             2017  Darling Downs South West              206
# 16             2017      Far North Queensland               96
# 17             2017              Metropolitan              247
# 18             2017               North Coast              218
# 19             2017          North Queensland              105
# 20             2017                South East              165
# 21             2018        Central Queensland              185
# 22             2018  Darling Downs South West              206
# 23             2018      Far North Queensland               96
# 24             2018              Metropolitan              247
# 25             2018               North Coast              219
# 26             2018          North Queensland              106
# 27             2018                South East              167
# 28             2019        Central Queensland              185
# 29             2019  Darling Downs South West              206
# 30             2019      Far North Queensland               96
# 31             2019              Metropolitan              249
# 32             2019               North Coast              219
# 33             2019          North Queensland              106
# 34             2019                South East              167

# %%
df4b = pd.pivot_table(df4a,values = 'Attendance Rate',index=['Attendance Year'],columns = ['Region']).reset_index()

df4b
# Out:
# Region  Attendance Year  Central Queensland  Darling Downs South West  \
# 0                  2015                 185                       206
# 1                  2016                 185                       206
# 2                  2017                 185                       206
# 3                  2018                 185                       206
# 4                  2019                 185                       206
#
# Region  Far North Queensland  Metropolitan  North Coast  North Queensland  \
# 0                         95           244          215               105
# 1                         95           245          217               105
# 2                         96           247          218               105
# 3                         96           247          219               106
# 4                         96           249          219               106
#
# Region  South East
# 0              165
# 1              165
# 2              165
# 3              167
# 4              167

# %%
#plot multiple pie charts all together in one fig
def func(pct,abvalue):
    absolute = float(pct/100*np.sum(abvalue))
    return '{:.2f}%'.format(absolute)

fig, axes = plt.subplots(3,2,figsize=(20,15))
for i,(idx, row) in enumerate(df4b.set_index('Attendance Year').iterrows()):
    ax = axes[i//2,i%2]
    ax.pie(row,labels = row.index, autopct='%1.1f%%',startangle=90);
    ax.set_title(idx)
    ax.axis('equal')

axes[2,1].axis('off')
fig.subplots_adjust(wspace=0.1)
plt.savefig('../data/fig2_part2_Attendance Rate & Region_pie.png')

# %%
#select interested data and form new dfs
df5 = df2.groupby(['Attendance Year','Local Government Area']).mean().reset_index()

df5
# Out:
#      Attendance Year Local Government Area  Attendance Rate
# 0               2015           Aurukun (S)        59.700000
# 1               2015           Balonne (S)        89.066667
# 2               2015            Banana (S)        93.092857
# 3               2015        Barcaldine (R)        93.140000
# 4               2015            Barcoo (S)        96.633333
# ..               ...                   ...              ...
# 361             2019     Western Downs (R)        91.528571
# 362             2019        Whitsunday (R)        91.261538
# 363             2019            Winton (S)        87.800000
# 364             2019        Woorabinda (S)        72.100000
# 365             2019          Yarrabah (S)        62.300000
#
# [366 rows x 3 columns]

# %%
#check out in details
df5['Local Government Area'].unique()
# Out:
# array(['Aurukun (S)', 'Balonne (S)', 'Banana (S)', 'Barcaldine (R)',
#        'Barcoo (S)', 'Blackall Tambo (R)', 'Boulia (S)', 'Brisbane (C)',
#        'Bulloo (S)', 'Bundaberg (R)', 'Burdekin (S)', 'Burke (S)',
#        'Cairns (R)', 'Carpentaria (S)', 'Cassowary Coast (R)',
#        'Central Highlands (R)', 'Charters Towers (R)', 'Cherbourg (S)',
#        'Cloncurry (S)', 'Cook (S)', 'Croydon (S)', 'Diamantina (S)',
#        'Doomadgee (S)', 'Douglas (S)', 'Etheridge (S)', 'Flinders (S)',
#        'Fraser Coast (R)', 'Gladstone (R)', 'Gold Coast (C)',
#        'Goondiwindi (R)', 'Gympie (R)', 'Hinchinbrook (S)', 'Ipswich (C)',
#        'Isaac (R)', 'Kowanyama (S)', 'Livingstone (S)',
#        'Lockhart River (S)', 'Lockyer Valley (R)', 'Logan (C)',
#        'Longreach (R)', 'Mackay (R)', 'Maranoa (R)', 'Mareeba (S)',
#        'McKinlay (S)', 'Moreton Bay (R)', 'Mornington (S)',
#        'Mount Isa (C)', 'Murweh (S)', 'Noosa (S)', 'North Burnett (R)',
#        'Northern Peninsula Area (R)', 'Palm Island (S)', 'Paroo (S)',
#        'Pormpuraaw (S)', 'Quilpie (S)', 'Redland (C)', 'Richmond (S)',
#        'Rockhampton (R)', 'Scenic Rim (R)', 'Somerset (R)',
#        'South Burnett (R)', 'Southern Downs (R)', 'Sunshine Coast (R)',
#        'Tablelands (R)', 'Toowoomba (R)', 'Torres (S)', 'Townsville (C)',
#        'Weipa (T)', 'Western Downs (R)', 'Whitsunday (R)', 'Winton (S)',
#        'Woorabinda (S)', 'Yarrabah (S)', 'Hope Vale (S)'], dtype=object)

# %%
#check out in details
len(df5['Local Government Area'].unique())
# Out:
# 74

# %%
#change the view for plotting
df6 = pd.pivot_table(df5,values = 'Attendance Rate',index= ['Attendance Year'],
                     columns =['Local Government Area']).reset_index()

df6
# Out:
# Local Government Area  Attendance Year  Aurukun (S)  Balonne (S)  Banana (S)  \
# 0                                 2015         59.7    89.066667   93.092857
# 1                                 2016         47.8    90.416667   93.242857
# 2                                 2017         55.9    90.350000   92.750000
# 3                                 2018         53.9    87.116667   91.942857
# 4                                 2019         42.5    88.833333   92.071429
#
# Local Government Area  Barcaldine (R)  Barcoo (S)  Blackall Tambo (R)  \
# 0                               93.14   96.633333               92.60
# 1                               93.72   92.633333               89.80
# 2                               91.70   91.366667               90.75
# 3                               89.92   90.333333               90.15
# 4                               90.86   86.733333               88.20
#
# Local Government Area  Boulia (S)  Brisbane (C)  Bulloo (S)  ...  \
# 0                           78.05     92.995604        92.9  ...
# 1                           90.25     93.290659        91.4  ...
# 2                           84.45     93.095604        94.6  ...
# 3                           90.35     92.462088        92.5  ...
# 4                           88.70     92.099454        89.2  ...
#
# Local Government Area  Tablelands (R)  Toowoomba (R)  Torres (S)  \
# 0                           90.569231      92.936207        87.5
# 1                           90.669231      92.786207        89.0
# 2                           90.869231      92.805172        87.8
# 3                           90.084615      92.325862        86.7
# 4                           89.292308      92.353448        85.8
#
# Local Government Area  Townsville (C)  Weipa (T)  Western Downs (R)  \
# 0                           90.502857       81.6          92.732143
# 1                           90.282857       82.9          92.482143
# 2                           90.160000       82.4          92.067857
# 3                           89.500000       78.6          91.332143
# 4                           88.361111       79.6          91.528571
#
# Local Government Area  Whitsunday (R)  Winton (S)  Woorabinda (S)  \
# 0                           91.438462        90.5            86.6
# 1                           91.846154        92.1            85.0
# 2                           91.846154        93.3            89.7
# 3                           91.600000        91.5            81.2
# 4                           91.261538        87.8            72.1
#
# Local Government Area  Yarrabah (S)
# 0                              67.6
# 1                              67.1
# 2                              62.7
# 3                              61.4
# 4                              62.3
#
# [5 rows x 75 columns]

# %%
#remove nan value and show the rest
df6 = df6.dropna(axis=1)

df6.columns
# Out:
# Index(['Attendance Year', 'Aurukun (S)', 'Balonne (S)', 'Banana (S)',
#        'Barcaldine (R)', 'Barcoo (S)', 'Blackall Tambo (R)', 'Boulia (S)',
#        'Brisbane (C)', 'Bulloo (S)', 'Bundaberg (R)', 'Burdekin (S)',
#        'Burke (S)', 'Cairns (R)', 'Carpentaria (S)', 'Cassowary Coast (R)',
#        'Central Highlands (R)', 'Charters Towers (R)', 'Cherbourg (S)',
#        'Cloncurry (S)', 'Cook (S)', 'Croydon (S)', 'Diamantina (S)',
#        'Doomadgee (S)', 'Douglas (S)', 'Etheridge (S)', 'Flinders (S)',
#        'Fraser Coast (R)', 'Gladstone (R)', 'Gold Coast (C)',
#        'Goondiwindi (R)', 'Gympie (R)', 'Hinchinbrook (S)', 'Ipswich (C)',
#        'Isaac (R)', 'Kowanyama (S)', 'Livingstone (S)', 'Lockhart River (S)',
#        'Lockyer Valley (R)', 'Logan (C)', 'Longreach (R)', 'Mackay (R)',
#        'Maranoa (R)', 'Mareeba (S)', 'McKinlay (S)', 'Moreton Bay (R)',
#        'Mornington (S)', 'Mount Isa (C)', 'Murweh (S)', 'Noosa (S)',
#        'North Burnett (R)', 'Northern Peninsula Area (R)', 'Palm Island (S)',
#        'Paroo (S)', 'Pormpuraaw (S)', 'Quilpie (S)', 'Redland (C)',
#        'Richmond (S)', 'Rockhampton (R)', 'Scenic Rim (R)', 'Somerset (R)',
#        'South Burnett (R)', 'Southern Downs (R)', 'Sunshine Coast (R)',
#        'Tablelands (R)', 'Toowoomba (R)', 'Torres (S)', 'Townsville (C)',
#        'Weipa (T)', 'Western Downs (R)', 'Whitsunday (R)', 'Winton (S)',
#        'Woorabinda (S)', 'Yarrabah (S)'],
#       dtype='object', name='Local Government Area')

# %%
#change the column order to have a better view of plot later
df6 = df6[['Attendance Year',
           'Aurukun (S)','Balonne (S)','Banana (S)','Barcoo (S)','Boulia (S)','Bulloo (S)','Burdekin (S)',
           'Burke (S)','Carpentaria (S)','Cherbourg (S)','Cloncurry (S)','Cook (S)','Croydon (S)','Diamantina (S)',
           'Doomadgee (S)','Douglas (S)','Etheridge (S)','Flinders (S)','Hinchinbrook (S)','Kowanyama (S)','Livingstone (S)',
           'Lockhart River (S)','Mareeba (S)','McKinlay (S)','Mornington (S)','Murweh (S)','Noosa (S)','Palm Island (S)',
           'Paroo (S)','Pormpuraaw (S)','Quilpie (S)','Richmond (S)','Torres (S)','Winton (S)','Woorabinda (S)',
           'Yarrabah (S)',
           'Barcaldine (R)','Blackall Tambo (R)','Bundaberg (R)','Cairns (R)','Cassowary Coast (R)','Central Highlands (R)', 'Charters Towers (R)',
           'Fraser Coast (R)','Gladstone (R)','Goondiwindi (R)','Gympie (R)','Isaac (R)','Lockyer Valley (R)','Longreach (R)',
           'Mackay (R)','Maranoa (R)','Moreton Bay (R)','North Burnett (R)','Northern Peninsula Area (R)','Rockhampton (R)','Scenic Rim (R)',
           'Somerset (R)','South Burnett (R)','Southern Downs (R)','Sunshine Coast (R)','Tablelands (R)','Toowoomba (R)','Western Downs (R)',
           'Whitsunday (R)',
           'Brisbane (C)','Gold Coast (C)','Ipswich (C)','Logan (C)','Mount Isa (C)','Redland (C)','Townsville (C)',
           'Weipa (T)']]

df6
# Out:
# Local Government Area  Attendance Year  Aurukun (S)  Balonne (S)  Banana (S)  \
# 0                                 2015         59.7    89.066667   93.092857
# 1                                 2016         47.8    90.416667   93.242857
# 2                                 2017         55.9    90.350000   92.750000
# 3                                 2018         53.9    87.116667   91.942857
# 4                                 2019         42.5    88.833333   92.071429
#
# Local Government Area  Barcoo (S)  Boulia (S)  Bulloo (S)  Burdekin (S)  \
# 0                       96.633333       78.05        92.9     92.460000
# 1                       92.633333       90.25        91.4     91.213333
# 2                       91.366667       84.45        94.6     91.066667
# 3                       90.333333       90.35        92.5     90.266667
# 4                       86.733333       88.70        89.2     90.253333
#
# Local Government Area  Burke (S)  Carpentaria (S)  ...  Western Downs (R)  \
# 0                           85.6            84.95  ...          92.732143
# 1                           79.6            79.90  ...          92.482143
# 2                           80.0            81.90  ...          92.067857
# 3                           77.0            80.70  ...          91.332143
# 4                           77.0            80.05  ...          91.528571
#
# Local Government Area  Whitsunday (R)  Brisbane (C)  Gold Coast (C)  \
# 0                           91.438462     92.995604       91.853731
# 1                           91.846154     93.290659       92.158209
# 2                           91.846154     93.095604       92.011940
# 3                           91.600000     92.462088       91.704412
# 4                           91.261538     92.099454       91.514706
#
# Local Government Area  Ipswich (C)  Logan (C)  Mount Isa (C)  Redland (C)  \
# 0                        90.941860  90.411765      86.988889    91.591304
# 1                        91.204545  90.723529      86.877778    91.891304
# 2                        91.126087  90.847059      87.877778    91.713043
# 3                        90.213043  90.136538      86.555556    91.378261
# 4                        89.412766  89.690385      83.711111    91.026087
#
# Local Government Area  Townsville (C)  Weipa (T)
# 0                           90.502857       81.6
# 1                           90.282857       82.9
# 2                           90.160000       82.4
# 3                           89.500000       78.6
# 4                           88.361111       79.6
#
# [5 rows x 74 columns]

# %%
#change the view of dataframe
df7 = df6.groupby(df6['Attendance Year']).first()

df8 = df7.T

df8
# Out:
# Attendance Year             2015       2016       2017       2018       2019
# Local Government Area
# Aurukun (S)            59.700000  47.800000  55.900000  53.900000  42.500000
# Balonne (S)            89.066667  90.416667  90.350000  87.116667  88.833333
# Banana (S)             93.092857  93.242857  92.750000  91.942857  92.071429
# Barcoo (S)             96.633333  92.633333  91.366667  90.333333  86.733333
# Boulia (S)             78.050000  90.250000  84.450000  90.350000  88.700000
# ...                          ...        ...        ...        ...        ...
# Logan (C)              90.411765  90.723529  90.847059  90.136538  89.690385
# Mount Isa (C)          86.988889  86.877778  87.877778  86.555556  83.711111
# Redland (C)            91.591304  91.891304  91.713043  91.378261  91.026087
# Townsville (C)         90.502857  90.282857  90.160000  89.500000  88.361111
# Weipa (T)              81.600000  82.900000  82.400000  78.600000  79.600000
#
# [73 rows x 5 columns]

# %%
#set line plot
df8.plot(kind='line',figsize=(20,15));
x_axis = np.arange(0,73,1)

tick_location = [value for value in x_axis]
plt.xticks(tick_location,list(df8.index),rotation='vertical')

plt.ylabel('Avg Attendance Rate')
plt.title('Avg Attendance Rate vs. LGA for each year')
plt.grid()
plt.savefig('../data/fig3_Part2_Attendance Rate & LGA_line.png')
