# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from scipy.stats import linregress

# %%
raw_df = pd.read_csv("../data/SEIFA-2016-by-post-code-cleaned.csv")
post_df = raw_df[["Postal Area Code", "  Rank within State or Territory - Decile"]]
post_df.columns = ["Post Code", "SERank"]
post_df
# raw_df.columns
# Out:
#       Post Code  SERank
# 0           800      10
# 1           810       8
# 2           812       7
# 3           815      10
# 4           820       9
# ...         ...     ...
# 2624       7466       4
# 2625       7467       1
# 2626       7468       6
# 2627       7469       1
# 2628       7470       2
#
# [2629 rows x 2 columns]

# %%
post_df["Post Code"].nunique()
# Out:
# 2629

# %%
post_df["SERank"].value_counts()
# Out:
# 9     267
# 7     266
# 3     266
# 5     265
# 6     263
# 2     262
# 8     261
# 4     261
# 1     259
# 10    259
# Name: SERank, dtype: int64

# %%
seifa_df = pd.read_csv("../data/cleaned_data_schoolattendancerate_seifa.csv")
seifa_df
# Out:
#      School Code                 School  Attendance Year   School Type  \
# 0            591  Abercorn State School             2015  State School
# 1            591  Abercorn State School             2016  State School
# 2            591  Abercorn State School             2017  State School
# 3            591  Abercorn State School             2018  State School
# 4            591  Abercorn State School             2019  State School
# ...          ...                    ...              ...           ...
# 6104         275  Zillmere State School             2015  State School
# 6105         275  Zillmere State School             2016  State School
# 6106         275  Zillmere State School             2017  State School
# 6107         275  Zillmere State School             2018  State School
# 6108         275  Zillmere State School             2019  State School
#
#      School Category            Remoteness Area              Region  \
# 0            Primary   Outer Regional Australia  Central Queensland
# 1            Primary   Outer Regional Australia  Central Queensland
# 2            Primary   Outer Regional Australia  Central Queensland
# 3            Primary   Outer Regional Australia  Central Queensland
# 4            Primary   Outer Regional Australia  Central Queensland
# ...              ...                        ...                 ...
# 6104         Primary  Major Cities of Australia        Metropolitan
# 6105         Primary  Major Cities of Australia        Metropolitan
# 6106         Primary  Major Cities of Australia        Metropolitan
# 6107         Primary  Major Cities of Australia        Metropolitan
# 6108         Primary  Major Cities of Australia        Metropolitan
#
#      Local Government Area State Electorate  FTE Days Attended  \
# 0        North Burnett (R)          Callide             1987.5
# 1        North Burnett (R)          Callide             1632.5
# 2        North Burnett (R)          Callide             1405.0
# 3        North Burnett (R)          Callide             1640.0
# 4        North Burnett (R)          Callide             1657.5
# ...                    ...              ...                ...
# 6104          Brisbane (C)           Aspley            11786.0
# 6105          Brisbane (C)           Aspley            12816.5
# 6106          Brisbane (C)           Aspley            11195.0
# 6107          Brisbane (C)           Aspley            12004.0
# 6108          Brisbane (C)           Aspley            10843.5
#
#       Possible Attendance Days  Attendance Rate  SEIFA Territory Percentile  \
# 0                       2103.0             94.5                        11.0
# 1                       1705.0             95.7                        11.0
# 2                       1440.0             97.6                        11.0
# 3                       1700.0             96.5                        11.0
# 4                       1728.0             95.9                        11.0
# ...                        ...              ...                         ...
# 6104                   12919.0             91.2                        78.0
# 6105                   13956.0             91.8                        78.0
# 6106                   12314.0             90.9                        78.0
# 6107                   13503.0             88.9                        78.0
# 6108                   12567.0             86.3                        78.0
#
#      Official Low Year Level Official High Year Level    Suburb  Post Code  \
# 0                  Prep Year                   Year 6  Abercorn       4627
# 1                  Prep Year                   Year 6  Abercorn       4627
# 2                  Prep Year                   Year 6  Abercorn       4627
# 3                  Prep Year                   Year 6  Abercorn       4627
# 4                  Prep Year                   Year 6  Abercorn       4627
# ...                      ...                      ...       ...        ...
# 6104               Prep Year                   Year 6  Zillmere       4034
# 6105               Prep Year                   Year 6  Zillmere       4034
# 6106               Prep Year                   Year 6  Zillmere       4034
# 6107               Prep Year                   Year 6  Zillmere       4034
# 6108               Prep Year                   Year 6  Zillmere       4034
#
#       All Student Count   Longitude   Latitude
# 0                  18.0  151.127031 -25.135955
# 1                  18.0  151.127031 -25.135955
# 2                  18.0  151.127031 -25.135955
# 3                  18.0  151.127031 -25.135955
# 4                  18.0  151.127031 -25.135955
# ...                 ...         ...        ...
# 6104              130.0  153.037355 -27.364673
# 6105              130.0  153.037355 -27.364673
# 6106              130.0  153.037355 -27.364673
# 6107              130.0  153.037355 -27.364673
# 6108              130.0  153.037355 -27.364673
#
# [6109 rows x 20 columns]

# %%
combine_df = seifa_df.merge(post_df, how="left", on="Post Code")
combine_df
# Out:
#      School Code                 School  Attendance Year   School Type  \
# 0            591  Abercorn State School             2015  State School
# 1            591  Abercorn State School             2016  State School
# 2            591  Abercorn State School             2017  State School
# 3            591  Abercorn State School             2018  State School
# 4            591  Abercorn State School             2019  State School
# ...          ...                    ...              ...           ...
# 6104         275  Zillmere State School             2015  State School
# 6105         275  Zillmere State School             2016  State School
# 6106         275  Zillmere State School             2017  State School
# 6107         275  Zillmere State School             2018  State School
# 6108         275  Zillmere State School             2019  State School
#
#      School Category            Remoteness Area              Region  \
# 0            Primary   Outer Regional Australia  Central Queensland
# 1            Primary   Outer Regional Australia  Central Queensland
# 2            Primary   Outer Regional Australia  Central Queensland
# 3            Primary   Outer Regional Australia  Central Queensland
# 4            Primary   Outer Regional Australia  Central Queensland
# ...              ...                        ...                 ...
# 6104         Primary  Major Cities of Australia        Metropolitan
# 6105         Primary  Major Cities of Australia        Metropolitan
# 6106         Primary  Major Cities of Australia        Metropolitan
# 6107         Primary  Major Cities of Australia        Metropolitan
# 6108         Primary  Major Cities of Australia        Metropolitan
#
#      Local Government Area State Electorate  FTE Days Attended  ...  \
# 0        North Burnett (R)          Callide             1987.5  ...
# 1        North Burnett (R)          Callide             1632.5  ...
# 2        North Burnett (R)          Callide             1405.0  ...
# 3        North Burnett (R)          Callide             1640.0  ...
# 4        North Burnett (R)          Callide             1657.5  ...
# ...                    ...              ...                ...  ...
# 6104          Brisbane (C)           Aspley            11786.0  ...
# 6105          Brisbane (C)           Aspley            12816.5  ...
# 6106          Brisbane (C)           Aspley            11195.0  ...
# 6107          Brisbane (C)           Aspley            12004.0  ...
# 6108          Brisbane (C)           Aspley            10843.5  ...
#
#       Attendance Rate  SEIFA Territory Percentile  Official Low Year Level  \
# 0                94.5                        11.0                Prep Year
# 1                95.7                        11.0                Prep Year
# 2                97.6                        11.0                Prep Year
# 3                96.5                        11.0                Prep Year
# 4                95.9                        11.0                Prep Year
# ...               ...                         ...                      ...
# 6104             91.2                        78.0                Prep Year
# 6105             91.8                        78.0                Prep Year
# 6106             90.9                        78.0                Prep Year
# 6107             88.9                        78.0                Prep Year
# 6108             86.3                        78.0                Prep Year
#
#      Official High Year Level    Suburb Post Code  All Student Count  \
# 0                      Year 6  Abercorn      4627               18.0
# 1                      Year 6  Abercorn      4627               18.0
# 2                      Year 6  Abercorn      4627               18.0
# 3                      Year 6  Abercorn      4627               18.0
# 4                      Year 6  Abercorn      4627               18.0
# ...                       ...       ...       ...                ...
# 6104                   Year 6  Zillmere      4034              130.0
# 6105                   Year 6  Zillmere      4034              130.0
# 6106                   Year 6  Zillmere      4034              130.0
# 6107                   Year 6  Zillmere      4034              130.0
# 6108                   Year 6  Zillmere      4034              130.0
#
#        Longitude   Latitude  SERank
# 0     151.127031 -25.135955     2.0
# 1     151.127031 -25.135955     2.0
# 2     151.127031 -25.135955     2.0
# 3     151.127031 -25.135955     2.0
# 4     151.127031 -25.135955     2.0
# ...          ...        ...     ...
# 6104  153.037355 -27.364673     8.0
# 6105  153.037355 -27.364673     8.0
# 6106  153.037355 -27.364673     8.0
# 6107  153.037355 -27.364673     8.0
# 6108  153.037355 -27.364673     8.0
#
# [6109 rows x 21 columns]

# %%
rank_stats = combine_df[["Post Code", "SERank", "Attendance Rate"]]
rank_stats
# Out:
#       Post Code  SERank  Attendance Rate
# 0          4627     2.0             94.5
# 1          4627     2.0             95.7
# 2          4627     2.0             97.6
# 3          4627     2.0             96.5
# 4          4627     2.0             95.9
# ...         ...     ...              ...
# 6104       4034     8.0             91.2
# 6105       4034     8.0             91.8
# 6106       4034     8.0             90.9
# 6107       4034     8.0             88.9
# 6108       4034     8.0             86.3
#
# [6109 rows x 3 columns]

# %%
rank_stats.dtypes
# Out:
# Post Code            int64
# SERank             float64
# Attendance Rate    float64
# dtype: object

# %%
rank_stats["SERank"].isnull().sum()
# Out:
# 10

# %%
rank_stats["Attendance Rate"].isnull().sum()
# Out:
# 0

# %%
rank_stats.dropna(axis=0, inplace=True)
rank_stats["SERank"].isnull().sum()
# Out:
# C:\Users\Natalie Manahan\anaconda3\envs\PythonData\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# 0

# %%
def plot_linear_regression(x_values, y_values, xlab, ylab, text_coordinates):
    
    (slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
    regress_values = x_values * slope + intercept
    line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
    
    # Plot
    plt.scatter(x_values,y_values)
    plt.plot(x_values,regress_values,"r-")
    plt.annotate(line_eq,text_coordinates,fontsize=15,color="red")
    plt.xlabel(xlab)
    plt.ylabel(ylab)
    print(f"The r-value is: {rvalue**2} pvalue: {pvalue}")
    plt.show()

# %%
y_values = rank_stats["Attendance Rate"]
x_values = rank_stats["SERank"]
plot_linear_regression(x_values, y_values, "SERank", 'Attendance Rate', (10, 100))
# Out:
# The r-value is: 0.08033250297152289 pvalue: 4.838562723842561e-113
